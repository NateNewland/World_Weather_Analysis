# %%
import random
import timeit
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
random.randint(-90,90)
# Out:
# 20

# %%
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# 86.3152912306583

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
latitudes
# Out:
# [14.845040064397738,
#  81.64274282591354,
#  65.83520539357552,
#  73.34727042208861,
#  -29.115418803626692,
#  -39.112550140638206,
#  -18.888717768139248,
#  54.26842719995289,
#  11.894073768956202,
#  -19.501887034639754]

# %%
random.randrange(-90, 90, step=1)
# Out:
# -67

# %%
np.random.uniform(-90.000,90.000, size=50)
# Out:
# array([ 42.06761215, -69.59853993, -82.98686487, -47.56287871,
#        -84.11050125,  48.99562559, -75.8533602 ,  44.10076349,
#          7.79126099,  89.92131203,  -2.83700202,  25.00706988,
#         12.71722225,  57.10224428,  66.18329704, -59.13208809,
#        -18.90240918, -26.12590735, -24.85970364,  10.54730244,
#        -86.87190129,  48.17413297, -85.17671435, -59.08448198,
#        -31.75289523, -60.70259291,  -6.5587351 ,  62.97414196,
#         73.46336253, -88.84353118,  53.16088493,  58.91640631,
#         73.47882899,  39.58390805, -33.58218247, -51.04553518,
#         27.13784192, -25.71400715,  12.89003417,  44.16508468,
#         89.6459017 ,  -5.07871243, -85.58945968,  -3.67322175,
#        -39.08076164, -45.36155508,   4.06770138,   3.91954823,
#         32.52953485,   3.19370019])

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 12.1 µs ± 22.1 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.59 ms ± 4.92 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# punta arenas cl
# tsihombe mg
# provideniya ru
# yar-sale ru
# ushuaia ar
# vardo no
# saint george bm
# timra se
# new norfolk au
# dekernes eg
# palu id
# taolanaro mg
# kupang id
# asfi ma
# puerto ayora ec
# argir fo
# tucupita ve
# taolanaro mg
# ushuaia ar
# victoria sc
# grand river south east mu
# busselton au
# birao cf
# mar del plata ar
# taolanaro mg
# richland us
# port lincoln au
# san julian bo
# nelson bay au
# upernavik gl
# butaritari ki
# bluff nz
# nurota uz
# mahebourg mu
# rivadavia ar
# bambous virieux mu
# lazaro cardenas mx
# ptuj si
# frontera mx
# thompson ca
# busselton au
# norman wells ca
# mapulo ph
# rikitea pf
# vaini to
# yantzaza ec
# rikitea pf
# ossora ru
# mataura pf
# kapaa us
# puerto ayora ec
# ushuaia ar
# jeremie ht
# port elizabeth za
# hilo us
# tuktoyaktuk ca
# hualmay pe
# mount isa au
# ushuaia ar
# taolanaro mg
# pattoki pk
# kapaa us
# vardo no
# ponta do sol cv
# doka sd
# calvinia za
# nanortalik gl
# saleaula ws
# punta arenas cl
# nouakchott mr
# albany au
# arinos br
# cherskiy ru
# sorland no
# punta arenas cl
# lolua tv
# nikolskoye ru
# atuona pf
# hobart au
# namibe ao
# labuhan id
# kaya bf
# blackwater au
# esperance au
# ribeira grande pt
# guarapari br
# deputatskiy ru
# kisanga tz
# hit iq
# praia cv
# vaini to
# nikolskoye ru
# duz tn
# port alfred za
# mataura pf
# albany au
# hobart au
# hermanus za
# rikitea pf
# avarua ck
# broome au
# rabo de peixe pt
# taolanaro mg
# nemuro jp
# chumikan ru
# hope ca
# clyde river ca
# miandrivazo mg
# bethel us
# avarua ck
# samarai pg
# nome us
# hilo us
# georgetown sh
# sentyabrskiy ru
# puerto madero mx
# tuatapere nz
# fairbanks us
# butaritari ki
# torbay ca
# busselton au
# betsiamites ca
# mataura pf
# beringovskiy ru
# hermanus za
# jamestown sh
# samalaeulu ws
# rikitea pf
# butaritari ki
# avarua ck
# bengkulu id
# port alfred za
# punta arenas cl
# soyo ao
# dolores ar
# port alfred za
# torbay ca
# clyde river ca
# georgetown sh
# carnarvon au
# tuktoyaktuk ca
# ahuimanu us
# kapaa us
# nador ma
# henties bay na
# khatanga ru
# sambava mg
# tepelene al
# san policarpo ph
# angren uz
# xinzhi cn
# hamilton bm
# punta arenas cl
# san carlos de bariloche ar
# kaitangata nz
# fortuna us
# kaitangata nz
# atuona pf
# chara ru
# illoqqortoormiut gl
# itoman jp
# cabo san lucas mx
# hobart au
# saint-philippe re
# eskisehir tr
# santa rosa ar
# vao nc

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 601

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed9d36f31a7df7a846f13a6edad24772

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed9d36f31a7df7a846f13a6edad24772&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":48.34,"feels_like":48.34,"temp_min":45.48,"temp_max":51.17,"pressure":1016,"humidity":73},"visibility":10000,"wind":{"speed":1.99,"deg":28,"gust":8.99},"clouds":{"all":75},"dt":1635456023,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1635419566,"sunset":1635457382},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 48.34,
#   'feels_like': 48.34,
#   'temp_min': 45.48,
#   'temp_max': 51.17,
#   'pressure': 1016,
#   'humidity': 73},
#  'visibility': 10000,
#  'wind': {'speed': 1.99, 'deg': 28, 'gust': 8.99},
#  'clouds': {'all': 75},
#  'dt': 1635456023,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1635419566,
#   'sunset': 1635457382},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 48.34,
#   'feels_like': 48.34,
#   'temp_min': 45.48,
#   'temp_max': 51.17,
#   'pressure': 1016,
#   'humidity': 73},
#  'visibility': 10000,
#  'wind': {'speed': 1.99, 'deg': 28, 'gust': 8.99},
#  'clouds': {'all': 75},
#  'dt': 1635456023,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1635419566,
#   'sunset': 1635457382},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 51.17 73 75 1.99

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 10, 28, 21, 20, 23)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | punta arenas
# Processing Record 2 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 13 | provideniya
# Processing Record 4 of Set 13 | yar-sale
# Processing Record 5 of Set 13 | ushuaia
# Processing Record 6 of Set 13 | vardo
# Processing Record 7 of Set 13 | saint george
# Processing Record 8 of Set 13 | timra
# Processing Record 9 of Set 13 | new norfolk
# Processing Record 10 of Set 13 | dekernes
# Processing Record 11 of Set 13 | palu
# Processing Record 12 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 13 | kupang
# Processing Record 14 of Set 13 | asfi
# Processing Record 15 of Set 13 | puerto ayora
# Processing Record 16 of Set 13 | argir
# Processing Record 17 of Set 13 | tucupita
# Processing Record 18 of Set 13 | victoria
# Processing Record 19 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 13 | busselton
# Processing Record 21 of Set 13 | birao
# Processing Record 22 of Set 13 | mar del plata
# Processing Record 23 of Set 13 | richland
# Processing Record 24 of Set 13 | port lincoln
# Processing Record 25 of Set 13 | san julian
# Processing Record 26 of Set 13 | rikitea
# Processing Record 27 of Set 13 | hithadhoo
# Processing Record 28 of Set 13 | polunochnoye
# Processing Record 29 of Set 13 | bermejo
# Processing Record 30 of Set 13 | cape town
# Processing Record 31 of Set 13 | sakakah
# Processing Record 32 of Set 13 | kruisfontein
# Processing Record 33 of Set 13 | albany
# Processing Record 34 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 13 | jamestown
# Processing Record 36 of Set 13 | matagami
# Processing Record 37 of Set 13 | qaanaaq
# Processing Record 38 of Set 13 | teya
# Processing Record 39 of Set 13 | carnarvon
# Processing Record 40 of Set 13 | port elizabeth
# Processing Record 41 of Set 13 | kavieng
# Processing Record 42 of Set 13 | changli
# Processing Record 43 of Set 13 | shieli
# Processing Record 44 of Set 13 | the valley
# Processing Record 45 of Set 13 | vaini
# Processing Record 46 of Set 13 | udachnyy
# Processing Record 47 of Set 13 | zaysan
# Processing Record 48 of Set 13 | tiksi
# Processing Record 49 of Set 13 | cockburn town
# Processing Record 50 of Set 13 | east london
# Processing Record 1 of Set 14 | kudat
# Processing Record 2 of Set 14 | pevek
# Processing Record 3 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 14 | grindavik
# Processing Record 5 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 14 | ruteng
# Processing Record 7 of Set 14 | ola
# Processing Record 8 of Set 14 | arraial do cabo
# Processing Record 9 of Set 14 | koping
# Processing Record 10 of Set 14 | yellowknife
# Processing Record 11 of Set 14 | ville-marie
# Processing Record 12 of Set 14 | chapais
# Processing Record 13 of Set 14 | kapaa
# Processing Record 14 of Set 14 | hobart
# Processing Record 15 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 14 | samarai
# Processing Record 18 of Set 14 | kodiak
# Processing Record 19 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 20 of Set 14 | mitsamiouli
# Processing Record 21 of Set 14 | suhbaatar
# Processing Record 22 of Set 14 | luwuk
# Processing Record 23 of Set 14 | mount isa
# Processing Record 24 of Set 14 | san quintin
# Processing Record 25 of Set 14 | natal
# Processing Record 26 of Set 14 | ostrovnoy
# Processing Record 27 of Set 14 | faanui
# Processing Record 28 of Set 14 | la asuncion
# Processing Record 29 of Set 14 | port blair
# Processing Record 30 of Set 14 | veraval
# Processing Record 31 of Set 14 | port alfred
# Processing Record 32 of Set 14 | henties bay
# Processing Record 33 of Set 14 | nuevo progreso
# Processing Record 34 of Set 14 | avarua
# Processing Record 35 of Set 14 | hasaki
# Processing Record 36 of Set 14 | cayenne
# Processing Record 37 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 14 | moba
# Processing Record 39 of Set 14 | imbituba
# Processing Record 40 of Set 14 | saldanha
# Processing Record 41 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 14 | barrow
# Processing Record 43 of Set 14 | bluff
# Processing Record 44 of Set 14 | ilulissat
# Processing Record 45 of Set 14 | kropotkin
# Processing Record 46 of Set 14 | longyearbyen
# Processing Record 47 of Set 14 | cherskiy
# Processing Record 48 of Set 14 | japura
# Processing Record 49 of Set 14 | tarakan
# Processing Record 50 of Set 14 | alofi
# Processing Record 1 of Set 15 | slave lake
# Processing Record 2 of Set 15 | aklavik
# Processing Record 3 of Set 15 | vostok
# Processing Record 4 of Set 15 | tariba
# Processing Record 5 of Set 15 | doha
# Processing Record 6 of Set 15 | coquimbo
# Processing Record 7 of Set 15 | nikolskoye
# Processing Record 8 of Set 15 | butaritari
# Processing Record 9 of Set 15 | bethel
# Processing Record 10 of Set 15 | hermanus
# Processing Record 11 of Set 15 | cidreira
# Processing Record 12 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 14 of Set 15 | dumra
# Processing Record 15 of Set 15 | tateyama
# Processing Record 16 of Set 15 | luderitz
# Processing Record 17 of Set 15 | tabat
# Processing Record 18 of Set 15 | delta
# Processing Record 19 of Set 15 | mataura
# Processing Record 20 of Set 15 | atuona
# Processing Record 21 of Set 15 | vanimo
# Processing Record 22 of Set 15 | bengkulu
# Processing Record 23 of Set 15 | sitka
# Processing Record 24 of Set 15 | cairns
# Processing Record 25 of Set 15 | vuktyl
# Processing Record 26 of Set 15 | cabo san lucas
# Processing Record 27 of Set 15 | ajdabiya
# Processing Record 28 of Set 15 | mkokotoni
# Processing Record 29 of Set 15 | caravelas
# Processing Record 30 of Set 15 | shaoyang
# Processing Record 31 of Set 15 | bilma
# Processing Record 32 of Set 15 | huarmey
# Processing Record 33 of Set 15 | tuktoyaktuk
# Processing Record 34 of Set 15 | tuatapere
# Processing Record 35 of Set 15 | le moule
# Processing Record 36 of Set 15 | thompson
# Processing Record 37 of Set 15 | iqaluit
# Processing Record 38 of Set 15 | tasiilaq
# Processing Record 39 of Set 15 | stonewall
# Processing Record 40 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 41 of Set 15 | saint-fabien
# City not found. Skipping...
# Processing Record 42 of Set 15 | falmouth
# Processing Record 43 of Set 15 | upata
# Processing Record 44 of Set 15 | carbonia
# Processing Record 45 of Set 15 | litovko
# Processing Record 46 of Set 15 | miraflores
# Processing Record 47 of Set 15 | diu
# Processing Record 48 of Set 15 | tianpeng
# Processing Record 14 of Set 17 | piacabucu
# Processing Record 15 of Set 17 | kenai
# Processing Record 16 of Set 17 | mogadishu
# Processing Record 17 of Set 17 | saint-augustin
# Processing Record 18 of Set 17 | taltal
# Processing Record 19 of Set 17 | stepnogorsk
# Processing Record 20 of Set 17 | hualmay
# Processing Record 21 of Set 17 | ambunti
# Processing Record 22 of Set 17 | jining
# Processing Record 23 of Set 17 | vila
# Processing Record 24 of Set 17 | bambous virieux
# Processing Record 25 of Set 17 | whangamata
# Processing Record 26 of Set 17 | altamira
# Processing Record 27 of Set 17 | belaya gora
# Processing Record 28 of Set 17 | russkaya polyana
# Processing Record 29 of Set 17 | da nang
# Processing Record 30 of Set 17 | mbandaka
# Processing Record 31 of Set 17 | luneburg
# Processing Record 32 of Set 17 | chuy
# Processing Record 33 of Set 17 | peniche
# Processing Record 34 of Set 17 | nakusp
# Processing Record 35 of Set 17 | pangai
# Processing Record 36 of Set 17 | isangel
# Processing Record 37 of Set 17 | shelburne
# Processing Record 38 of Set 17 | clyde river
# Processing Record 39 of Set 17 | kyshtovka
# Processing Record 40 of Set 17 | klaksvik
# Processing Record 41 of Set 17 | sungaipenuh
# Processing Record 42 of Set 17 | teahupoo
# Processing Record 43 of Set 17 | cartagena
# Processing Record 44 of Set 17 | mucuri
# Processing Record 45 of Set 17 | sorland
# Processing Record 46 of Set 17 | berlevag
# Processing Record 47 of Set 17 | tsienyane
# City not found. Skipping...
# Processing Record 48 of Set 17 | kahului
# Processing Record 49 of Set 17 | guerrero negro
# Processing Record 50 of Set 17 | upernavik
# Processing Record 1 of Set 18 | kambove
# Processing Record 2 of Set 18 | grand gaube
# Processing Record 3 of Set 18 | saint-philippe
# Processing Record 4 of Set 18 | calbuco
# Processing Record 5 of Set 18 | vila franca do campo
# Processing Record 6 of Set 18 | srednekolymsk
# Processing Record 7 of Set 18 | buchanan
# Processing Record 8 of Set 18 | nanyamba
# Processing Record 9 of Set 18 | sisimiut
# Processing Record 10 of Set 18 | hauterive
# Processing Record 11 of Set 18 | muisne
# Processing Record 12 of Set 18 | sarkand
# Processing Record 13 of Set 18 | mayo
# Processing Record 14 of Set 18 | lebu
# Processing Record 15 of Set 18 | atambua
# Processing Record 16 of Set 18 | san carlos de bariloche
# Processing Record 17 of Set 18 | labuhan
# Processing Record 18 of Set 18 | castro
# Processing Record 19 of Set 18 | bloomfield
# Processing Record 20 of Set 18 | ankang
# Processing Record 21 of Set 18 | tshikapa
# Processing Record 22 of Set 18 | sao filipe
# Processing Record 23 of Set 18 | salalah
# Processing Record 24 of Set 18 | miri
# Processing Record 25 of Set 18 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 18 | srivardhan
# Processing Record 27 of Set 18 | kushmurun
# Processing Record 28 of Set 18 | barra do bugres
# Processing Record 29 of Set 18 | shasta lake
# Processing Record 30 of Set 18 | kisangani
# Processing Record 31 of Set 18 | pahrump
# Processing Record 32 of Set 18 | presidencia roque saenz pena
# Processing Record 33 of Set 18 | chifeng
# Processing Record 34 of Set 18 | xining
# Processing Record 35 of Set 18 | cotonou
# Processing Record 36 of Set 18 | wagar
# Processing Record 37 of Set 18 | namibe
# Processing Record 38 of Set 18 | meulaboh
# Processing Record 39 of Set 18 | ancud
# Processing Record 40 of Set 18 | maghama
# City not found. Skipping...
# Processing Record 41 of Set 18 | faya
# Processing Record 42 of Set 18 | qaqortoq
# Processing Record 43 of Set 18 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 18 | kollumerland
# City not found. Skipping...
# Processing Record 45 of Set 18 | flinders
# Processing Record 46 of Set 18 | damghan
# Processing Record 47 of Set 18 | inhambane
# Processing Record 48 of Set 18 | eusebio ayala
# Processing Record 49 of Set 18 | maniwaki
# Processing Record 50 of Set 18 | santa rosalia
# Processing Record 1 of Set 19 | hilo
# Processing Record 2 of Set 19 | saskylakh
# Processing Record 3 of Set 19 | nanortalik
# Processing Record 4 of Set 19 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 19 | brigantine
# Processing Record 6 of Set 19 | coihaique
# Processing Record 7 of Set 19 | baruun-urt
# Processing Record 8 of Set 19 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 19 | borama
# City not found. Skipping...
# Processing Record 10 of Set 19 | ust-tsilma
# Processing Record 11 of Set 19 | marzuq
# Processing Record 12 of Set 19 | ucluelet
# Processing Record 13 of Set 19 | torbay
# Processing Record 14 of Set 19 | nome
# Processing Record 15 of Set 19 | riyadh
# Processing Record 16 of Set 19 | hohhot
# Processing Record 17 of Set 19 | ribeira grande
# Processing Record 18 of Set 19 | chase
# Processing Record 19 of Set 19 | banff
# Processing Record 20 of Set 19 | ambilobe
# Processing Record 21 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 19 | catamarca
# Processing Record 23 of Set 19 | dashitou
# Processing Record 24 of Set 19 | pangkalanbuun
# Processing Record 25 of Set 19 | geresk
# City not found. Skipping...
# Processing Record 26 of Set 19 | hami
# Processing Record 27 of Set 19 | eyl
# Processing Record 28 of Set 19 | port macquarie
# Processing Record 29 of Set 19 | lorengau
# Processing Record 30 of Set 19 | ginda
# Processing Record 31 of Set 19 | kpandae
# Processing Record 32 of Set 19 | hofn
# Processing Record 33 of Set 19 | gasa
# Processing Record 34 of Set 19 | lysyanka
# Processing Record 35 of Set 19 | san patricio
# Processing Record 36 of Set 19 | sola
# Processing Record 37 of Set 19 | bafia
# Processing Record 38 of Set 19 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 39 of Set 19 | lagoa
# Processing Record 40 of Set 19 | lasa
# Processing Record 41 of Set 19 | yarada
# Processing Record 42 of Set 19 | novikovo
# Processing Record 43 of Set 19 | kintinku
# Processing Record 44 of Set 19 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 19 | vlagtwedde
# Processing Record 46 of Set 19 | rotifunk
# Processing Record 47 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 19 | pouebo
# Processing Record 49 of Set 19 | shenjiamen
# Processing Record 50 of Set 19 | takoradi
# Processing Record 1 of Set 20 | cabcab
# Processing Record 2 of Set 20 | dekar
# Processing Record 3 of Set 20 | saint anthony
# Processing Record 4 of Set 20 | ayagoz
# Processing Record 5 of Set 20 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 20 | artyom
# Processing Record 7 of Set 20 | yulara
# Processing Record 8 of Set 20 | kidal
# Processing Record 9 of Set 20 | dunedin
# Processing Record 10 of Set 20 | benalla
# Processing Record 11 of Set 20 | zhob
# Processing Record 12 of Set 20 | padang
# Processing Record 13 of Set 20 | lavrentiya
# Processing Record 14 of Set 20 | montecristo
# Processing Record 15 of Set 20 | santa cruz
# Processing Record 16 of Set 20 | limbang
# Processing Record 17 of Set 20 | komsomolskiy
# Processing Record 18 of Set 20 | teknaf
# Processing Record 19 of Set 20 | guia de isora
# Processing Record 20 of Set 20 | atikokan
# Processing Record 21 of Set 20 | comodoro rivadavia
# Processing Record 22 of Set 20 | svetlogorsk
# Processing Record 23 of Set 20 | satka
# Processing Record 24 of Set 20 | kattivakkam
# Processing Record 25 of Set 20 | hobyo
# Processing Record 26 of Set 20 | praia da vitoria
# Processing Record 27 of Set 20 | seoul
# Processing Record 28 of Set 20 | constitucion
# Processing Record 29 of Set 20 | carauari
# Processing Record 30 of Set 20 | saeby
# Processing Record 31 of Set 20 | la ronge
# Processing Record 32 of Set 20 | ovsyanka
# Processing Record 33 of Set 20 | boa vista
# Processing Record 34 of Set 20 | samana
# Processing Record 35 of Set 20 | kerrville
# Processing Record 36 of Set 20 | pinawa
# Processing Record 37 of Set 20 | pangnirtung
# Processing Record 38 of Set 20 | krasnodon
# Processing Record 39 of Set 20 | kavaratti
# Processing Record 40 of Set 20 | hambantota
# Processing Record 41 of Set 20 | dakar
# Processing Record 42 of Set 20 | alcaniz
# Processing Record 43 of Set 20 | kachikau
# City not found. Skipping...
# Processing Record 44 of Set 20 | los llanos de aridane
# Processing Record 45 of Set 20 | pisco
# Processing Record 46 of Set 20 | fairbanks
# Processing Record 47 of Set 20 | koyilandi
# City not found. Skipping...
# Processing Record 48 of Set 20 | daan
# Processing Record 49 of Set 20 | kalemie
# Processing Record 50 of Set 20 | gisborne
# Processing Record 1 of Set 21 | jardim
# Processing Record 2 of Set 21 | okhotsk
# Processing Record 3 of Set 21 | eureka
# Processing Record 4 of Set 21 | flin flon
# Processing Record 5 of Set 21 | walvis bay
# Processing Record 6 of Set 21 | umea
# Processing Record 7 of Set 21 | pangody
# Processing Record 8 of Set 21 | katsuura
# Processing Record 9 of Set 21 | biak
# Processing Record 10 of Set 21 | dire
# Processing Record 11 of Set 21 | buluang
# Processing Record 12 of Set 21 | buga
# Processing Record 13 of Set 21 | sistranda
# Processing Record 14 of Set 21 | weihai
# Processing Record 15 of Set 21 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 21 | mae hong son
# Processing Record 17 of Set 21 | almirante
# Processing Record 18 of Set 21 | olinda
# Processing Record 19 of Set 21 | cap malheureux
# Processing Record 20 of Set 21 | devils lake
# Processing Record 21 of Set 21 | sabancuy
# Processing Record 22 of Set 21 | kolobrzeg
# Processing Record 23 of Set 21 | loksa
# Processing Record 24 of Set 21 | la baneza
# Processing Record 25 of Set 21 | hvolsvollur
# Processing Record 26 of Set 21 | sao felix do xingu
# Processing Record 27 of Set 21 | dmitriyevka
# Processing Record 28 of Set 21 | bilibino
# Processing Record 29 of Set 21 | la rioja
# Processing Record 30 of Set 21 | sayyan
# Processing Record 31 of Set 21 | ballina
# Processing Record 32 of Set 21 | lethem
# Processing Record 33 of Set 21 | volchansk
# Processing Record 34 of Set 21 | chara
# Processing Record 35 of Set 21 | pozhva
# Processing Record 36 of Set 21 | ribnitz-damgarten
# Processing Record 37 of Set 21 | kieta
# Processing Record 38 of Set 21 | zhanakorgan
# Processing Record 39 of Set 21 | laem sing
# Processing Record 40 of Set 21 | vilhena
# Processing Record 41 of Set 21 | sosua
# Processing Record 42 of Set 21 | mecca
# Processing Record 43 of Set 21 | warmbad
# Processing Record 44 of Set 21 | kamenka
# Processing Record 45 of Set 21 | giyani
# Processing Record 46 of Set 21 | sibolga
# Processing Record 47 of Set 21 | semey
# Processing Record 48 of Set 21 | marawi
# Processing Record 49 of Set 21 | george town
# Processing Record 50 of Set 21 | champerico
# Processing Record 1 of Set 22 | lithgow
# Processing Record 2 of Set 22 | vung tau
# Processing Record 3 of Set 22 | dingle
# Processing Record 4 of Set 22 | dujuma
# City not found. Skipping...
# Processing Record 5 of Set 22 | ghiror
# Processing Record 6 of Set 22 | pyapon
# Processing Record 7 of Set 22 | liaoyang
# Processing Record 8 of Set 22 | kampene
# Processing Record 9 of Set 22 | mabaruma
# Processing Record 10 of Set 22 | diamantino
# Processing Record 11 of Set 22 | quesnel
# Processing Record 12 of Set 22 | tsumeb
# Processing Record 13 of Set 22 | port-gentil
# Processing Record 14 of Set 22 | porto murtinho
# Processing Record 15 of Set 22 | bismarck
# Processing Record 16 of Set 22 | baracoa
# Processing Record 17 of Set 22 | maraba
# Processing Record 18 of Set 22 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 22 | mahebourg
# Processing Record 20 of Set 22 | hovd
# Processing Record 21 of Set 22 | paamiut
# Processing Record 22 of Set 22 | salinopolis
# Processing Record 23 of Set 22 | pacific grove
# Processing Record 24 of Set 22 | sorong
# Processing Record 25 of Set 22 | fortuna
# Processing Record 26 of Set 22 | xai-xai
# Processing Record 27 of Set 22 | sur
# Processing Record 28 of Set 22 | rio do sul
# Processing Record 29 of Set 22 | tamandare
# Processing Record 30 of Set 22 | albanel
# Processing Record 31 of Set 22 | vila velha
# Processing Record 32 of Set 22 | bowen
# Processing Record 33 of Set 22 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 22 | taoudenni
# Processing Record 35 of Set 22 | erenhot
# Processing Record 36 of Set 22 | asau
# Processing Record 37 of Set 22 | maningrida
# Processing Record 38 of Set 22 | aksarka
# Processing Record 39 of Set 22 | yagodnoye
# Processing Record 40 of Set 22 | angoche
# Processing Record 41 of Set 22 | ithaki
# Processing Record 42 of Set 22 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 22 | beringovskiy
# Processing Record 44 of Set 22 | zhongxing
# Processing Record 45 of Set 22 | rudbar
# Processing Record 46 of Set 22 | noshiro
# Processing Record 47 of Set 22 | augusto correa
# Processing Record 48 of Set 22 | rawson
# Processing Record 49 of Set 22 | tuscaloosa
# Processing Record 50 of Set 22 | uyuni
# Processing Record 1 of Set 23 | sergeyevka
# Processing Record 2 of Set 23 | cururupu
# Processing Record 3 of Set 23 | lompoc
# Processing Record 4 of Set 23 | baghdad
# Processing Record 5 of Set 23 | kosa
# Processing Record 6 of Set 23 | bac can
# City not found. Skipping...
# Processing Record 7 of Set 23 | cabedelo
# Processing Record 8 of Set 23 | coahuayana
# Processing Record 9 of Set 23 | port hedland
# Processing Record 10 of Set 23 | neyyattinkara
# Processing Record 11 of Set 23 | bandarbeyla
# Processing Record 12 of Set 23 | vavoua
# Processing Record 13 of Set 23 | banepa
# Processing Record 14 of Set 23 | yokadouma
# Processing Record 15 of Set 23 | whittlesea
# Processing Record 16 of Set 23 | bara
# Processing Record 17 of Set 23 | poya
# Processing Record 18 of Set 23 | tongliao
# Processing Record 19 of Set 23 | port hardy
# Processing Record 20 of Set 23 | saint-francois
# Processing Record 21 of Set 23 | birjand
# Processing Record 22 of Set 23 | ishcherskaya
# Processing Record 23 of Set 23 | lipin bor
# Processing Record 24 of Set 23 | milingimbi
# City not found. Skipping...
# Processing Record 25 of Set 23 | echirolles
# Processing Record 26 of Set 23 | sandy bay
# Processing Record 27 of Set 23 | la libertad
# Processing Record 28 of Set 23 | sioux lookout
# Processing Record 29 of Set 23 | goderich
# Processing Record 30 of Set 23 | narsaq
# Processing Record 31 of Set 23 | sao joao da barra
# Processing Record 32 of Set 23 | vestmannaeyjar
# Processing Record 33 of Set 23 | igunga
# Processing Record 34 of Set 23 | anadyr
# Processing Record 35 of Set 23 | tazovskiy
# Processing Record 36 of Set 23 | san pedro
# Processing Record 37 of Set 23 | fethiye
# Processing Record 38 of Set 23 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 23 | barcelona
# Processing Record 40 of Set 23 | kirakira
# Processing Record 41 of Set 23 | turukhansk
# Processing Record 42 of Set 23 | poum
# Processing Record 43 of Set 23 | chisec
# Processing Record 44 of Set 23 | holland
# Processing Record 45 of Set 23 | huancavelica
# Processing Record 46 of Set 23 | olonets
# Processing Record 47 of Set 23 | leningradskiy
# Processing Record 48 of Set 23 | wanxian
# Processing Record 49 of Set 23 | haines junction
# Processing Record 50 of Set 23 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 24 | guilin
# Processing Record 2 of Set 24 | amapa
# Processing Record 3 of Set 24 | pierre
# Processing Record 4 of Set 24 | montepuez
# Processing Record 5 of Set 24 | fort nelson
# Processing Record 6 of Set 24 | berezovyy
# Processing Record 7 of Set 24 | nelson bay
# Processing Record 8 of Set 24 | nurota
# Processing Record 9 of Set 24 | rivadavia
# Processing Record 10 of Set 24 | lazaro cardenas
# Processing Record 11 of Set 24 | ptuj
# Processing Record 12 of Set 24 | frontera
# Processing Record 13 of Set 24 | mapulo
# Processing Record 14 of Set 24 | yantzaza
# Processing Record 15 of Set 24 | ossora
# Processing Record 16 of Set 24 | jeremie
# Processing Record 17 of Set 24 | pattoki
# Processing Record 18 of Set 24 | doka
# Processing Record 19 of Set 24 | calvinia
# Processing Record 20 of Set 24 | nouakchott
# Processing Record 21 of Set 24 | arinos
# Processing Record 22 of Set 24 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 24 | kaya
# Processing Record 24 of Set 24 | blackwater
# Processing Record 25 of Set 24 | guarapari
# Processing Record 26 of Set 24 | deputatskiy
# Processing Record 27 of Set 24 | kisanga
# Processing Record 28 of Set 24 | hit
# Processing Record 29 of Set 24 | praia
# Processing Record 30 of Set 24 | duz
# City not found. Skipping...
# Processing Record 31 of Set 24 | broome
# Processing Record 32 of Set 24 | rabo de peixe
# Processing Record 33 of Set 24 | chumikan
# Processing Record 34 of Set 24 | hope
# Processing Record 35 of Set 24 | miandrivazo
# Processing Record 36 of Set 24 | puerto madero
# Processing Record 37 of Set 24 | betsiamites
# Processing Record 38 of Set 24 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 24 | soyo
# Processing Record 40 of Set 24 | dolores
# Processing Record 41 of Set 24 | ahuimanu
# Processing Record 42 of Set 24 | nador
# Processing Record 43 of Set 24 | sambava
# Processing Record 44 of Set 24 | tepelene
# Processing Record 45 of Set 24 | san policarpo
# Processing Record 46 of Set 24 | angren
# Processing Record 47 of Set 24 | xinzhi
# Processing Record 48 of Set 24 | itoman
# Processing Record 49 of Set 24 | eskisehir
# Processing Record 50 of Set 24 | santa rosa
# Processing Record 1 of Set 25 | vao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     60.91        51          90
# 1   Provideniya  64.3833 -173.3000     15.91        67          90
# 2      Yar-Sale  66.8333   70.8333     22.75        96         100
# 3       Ushuaia -54.8000  -68.3000     60.46        36          20
# 4         Vardo  70.3705   31.1107     32.20        93         100
# 5  Saint George  37.1041 -113.5841     77.47        31           1
# 6         Timra  62.4870   17.3257     37.11       100          90
# 7   New Norfolk -42.7826  147.0587     47.70        79         100
# 8      Dekernes  31.0876   31.5950     76.89        80          55
# 9          Palu  -0.8917  119.8707     74.91        94          97
#
#    Wind Speed Country                 Date
# 0       20.71      CL  2021-10-28 21:40:03
# 1        8.95      RU  2021-10-28 21:40:04
# 2       12.24      RU  2021-10-28 21:37:48
# 3       13.80      AR  2021-10-28 21:36:21
# 4       25.55      NO  2021-10-28 21:36:51
# 5        4.00      US  2021-10-28 21:37:00
# 6        3.44      SE  2021-10-28 21:40:06
# 7        5.01      AU  2021-10-28 21:40:07
# 8        6.24      EG  2021-10-28 21:40:07
# 9        3.00      ID  2021-10-28 21:40:08

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1   Provideniya  64.3833 -173.3000     15.91        67          90
# 2      Yar-Sale  66.8333   70.8333     22.75        96         100
# 4         Vardo  70.3705   31.1107     32.20        93         100
# 5  Saint George  37.1041 -113.5841     77.47        31           1
# 6         Timra  62.4870   17.3257     37.11       100          90
#
#    Wind Speed Country                 Date
# 1        8.95      RU  2021-10-28 21:40:04
# 2       12.24      RU  2021-10-28 21:37:48
# 4       25.55      NO  2021-10-28 21:36:51
# 5        4.00      US  2021-10-28 21:37:00
# 6        3.44      SE  2021-10-28 21:40:06

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \nfor % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \nfor % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \nfor Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \nfor Wind Speed', 'Wind Speed',(-50,35))
